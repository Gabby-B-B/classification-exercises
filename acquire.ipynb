# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import env
import os
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, MinMaxScaler
from pydataset import data

# %%
from env import host, user, password

# %%
def get_connection(db, user=env.user, host=env.host, password=env.password):
    return f'mysql+pymysql://{user}:{password}@{host}/{db}'

# %% [markdown]
# In a jupyter notebook, classification_exercises.ipynb, use a python module (pydata or seaborn datasets) containing datasets as a source from the iris data. Create a pandas dataframe, df_iris, from this data.
# <ul>
# <li>print the first 3 rows
# <li>print the number of rows and columns (shape)
# <li>print the column names
# <li>print the data type of each column
# <li>print the summary statistics for each of the numeric variables. Would you recommend rescaling the data based on these statistics?</ul>

# %%
iris = pd.read_sql('SELECT * FROM measurements', get_connection('iris_db'))

# %%
iris.to_csv('iris.csv')

# %%
def get_iris_data():
    filename = "iris.csv"
    if os.path.isfile(filename):
        return pd.read_csv(filename)
    else:
        # read the SQL query into a dataframe
        df = pd.read_sql('SELECT * FROM measuresments', get_connection('iris_db'))

        # Write that dataframe to disk for later. Called "caching" the data for later.
        df.to_file(filename)

        # Return the dataframe to the calling code
        return df

# %%
df_iris = pd.read_csv('iris.csv', index_col=0)
df_iris.head(3)
# Out:
#    measurement_id  sepal_length  sepal_width  petal_length  petal_width  \
# 0               1           5.1          3.5           1.4          0.2
# 1               2           4.9          3.0           1.4          0.2
# 2               3           4.7          3.2           1.3          0.2
#
#    species_id
# 0           1
# 1           1
# 2           1

# %%
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   measurement_id  150 non-null    int64
#  1   sepal_length    150 non-null    float64
#  2   sepal_width     150 non-null    float64
#  3   petal_length    150 non-null    float64
#  4   petal_width     150 non-null    float64
#  5   species_id      150 non-null    int64
# dtypes: float64(4), int64(2)
# memory usage: 8.2 KB

# %%
for col in df_iris.columns: 
    print(col)
# Out:
# measurement_id
# sepal_length
# sepal_width
# petal_length
# petal_width
# species_id

# %%
df_iris.dtypes
#based off the data types i would convert the measurement and species id from an integer to a float
# Out:
# measurement_id      int64
# sepal_length      float64
# sepal_width       float64
# petal_length      float64
# petal_width       float64
# species_id          int64
# dtype: object

# %% [markdown]
# Read the Table1_CustDetails table from the Excel_Exercises.xlsx file into a dataframe named df_excel.
# <ol>
# <li> assign the first 100 rows to a new dataframe, df_excel_sample
# <li>print the number of rows of your original dataframe
# <li>print the first 5 column names
# <li>print the column names that have a data type of object
# <li>compute the range for each of the numeric variables.
#     </ol>

# %%
excel_df = pd.read_csv('telco.csv', index_col=0)
excel_df.head(100)
# Out:
#              gender  is_senior_citizen partner dependents  phone_service  \
# customer_id
# 0002-ORFBO   Female                  0     Yes        Yes              1
# 0003-MKNFE     Male                  0      No         No              2
# 0004-TLHLJ     Male                  0      No         No              1
# 0011-IGKFF     Male                  1     Yes         No              1
# 0013-EXCHZ   Female                  1     Yes         No              1
# 0013-MHZWF   Female                  0      No        Yes              1
# 0013-SMEOE   Female                  1     Yes         No              1
# 0014-BMAQU     Male                  0     Yes         No              2
# 0015-UOCOJ   Female                  1      No         No              1
# 0016-QLJIS   Female                  0     Yes        Yes              2
# 0017-DINOC     Male                  0      No         No              0
# 0017-IUDMW   Female                  0     Yes        Yes              2
# 0018-NYROU   Female                  0     Yes         No              1
# 0019-EFAEP   Female                  0      No         No              2
# 0019-GFNTW   Female                  0      No         No              0
# 0020-INWCK   Female                  0     Yes        Yes              2
# 0020-JDNXP   Female                  0     Yes        Yes              0
# 0021-IKXGC   Female                  1      No         No              2
# 0022-TCJCI     Male                  1      No         No              1
# 0023-HGHWL     Male                  1      No         No              0
# 0023-UYUPN   Female                  1     Yes         No              2
# 0023-XUOPT   Female                  0     Yes         No              2
# 0027-KWYKW   Female                  0     Yes        Yes              2
# 0030-FNXPP   Female                  0      No         No              1
# 0031-PVLZI   Female                  0     Yes        Yes              1
# 0032-PGELS   Female                  0     Yes        Yes              0
# 0036-IHMOT   Female                  0     Yes        Yes              1
# 0040-HALCW     Male                  0     Yes        Yes              1
# 0042-JVWOJ     Male                  0      No         No              1
# 0042-RLHYP   Female                  0     Yes        Yes              1
# 0048-LUMLS     Male                  0     Yes        Yes              1
# 0048-PIHNL   Female                  0     Yes         No              1
# 0052-DCKON     Male                  0     Yes         No              2
# 0052-YNYOT   Female                  0      No         No              1
# 0056-EPFBG     Male                  0     Yes        Yes              0
# 0057-QBUQH   Female                  0      No        Yes              2
# 0058-EVZWM   Female                  0     Yes         No              2
# 0060-FUALY   Female                  0     Yes         No              2
# 0064-SUDOG   Female                  0     Yes        Yes              1
# 0064-YIJGF     Male                  0     Yes        Yes              2
# 0067-DKWBL     Male                  1      No         No              1
# 0068-FIGTF   Female                  0      No         No              1
# 0071-NDAFP     Male                  0     Yes        Yes              2
# 0074-HDKDG     Male                  0     Yes        Yes              1
# 0076-LVEPS     Male                  0      No        Yes              0
# 0078-XZMHT     Male                  0     Yes         No              2
# 0080-EMYVY   Female                  0      No         No              1
# 0080-OROZO   Female                  0      No         No              1
# 0082-LDZUE     Male                  0      No         No              1
# 0082-OQIQY     Male                  0      No         No              1
# 0083-PIVIK     Male                  0      No         No              2
# 0089-IIQKO   Female                  0     Yes        Yes              2
# 0093-EXYQL   Female                  1      No         No              1
# 0093-XWZFY     Male                  0      No         No              2
# 0094-OIFMO   Female                  1      No         No              1
# 0096-BXERS   Female                  0     Yes         No              2
# 0096-FCPUF     Male                  0      No         No              2
# 0098-BOWSO     Male                  0      No         No              1
# 0100-DUVFC     Male                  1     Yes         No              2
# 0103-CSITQ   Female                  0     Yes         No              2
# 0104-PPXDV     Male                  0     Yes         No              1
# 0106-GHRQR     Male                  0      No         No              2
# 0106-UGRDO   Female                  0     Yes         No              2
# 0107-WESLM     Male                  0      No         No              1
# 0107-YHINA     Male                  0      No        Yes              2
# 0111-KLBQG     Male                  1     Yes        Yes              1
# 0112-QAWRZ     Male                  0     Yes        Yes              2
# 0112-QWPNC     Male                  0     Yes         No              2
# 0114-IGABW   Female                  0     Yes         No              0
# 0114-PEGZZ   Female                  0      No         No              2
# 0114-RSRRW   Female                  0     Yes         No              1
# 0115-TFERT     Male                  0     Yes         No              2
# 0117-LFRMW     Male                  0     Yes        Yes              0
# 0118-JPNOY   Female                  1      No         No              1
# 0121-SNYRK     Male                  0      No         No              0
# 0122-OAHPZ   Female                  0      No         No              2
# 0123-CRBRT   Female                  0     Yes        Yes              2
# 0125-LZQXK     Male                  0      No         No              1
# 0128-MKWSG   Female                  0      No        Yes              0
# 0129-KPTWJ     Male                  0     Yes         No              1
# 0129-QMPDR     Male                  0     Yes        Yes              1
# 0130-SXOUN     Male                  0      No         No              2
# 0133-BMFZO   Female                  0      No         No              1
# 0134-XWXCE   Female                  1      No         No              1
# 0135-NMXAP   Female                  0      No         No              2
# 0136-IFMYD     Male                  1     Yes         No              2
# 0137-OCGAB   Female                  0      No         No              2
# 0137-UDEUO   Female                  0      No         No              1
# 0139-IVFJG   Female                  0     Yes         No              1
# 0141-YEAYS   Female                  1      No         No              2
# 0142-GVYSN     Male                  0      No         No              1
# 0147-ESWWR   Female                  1     Yes         No              2
# 0148-DCDOS     Male                  0      No         No              2
# 0151-ONTOV   Female                  0      No         No              1
# 0156-FVPTA     Male                  0     Yes         No              1
# 0164-APGRB   Female                  0      No         No              2
# 0164-XAIRP   Female                  0      No         No              1
# 0168-XZKBB   Female                  0     Yes         No              2
# 0174-QRVVY     Male                  0     Yes        Yes              2
# 0177-PXBAT     Male                  1     Yes         No              2
#
#              internet_service  contract_type               payment_type  \
# customer_id
# 0002-ORFBO                  1              1               Mailed check
# 0003-MKNFE                  1              0               Mailed check
# 0004-TLHLJ                  2              0           Electronic check
# 0011-IGKFF                  2              0           Electronic check
# 0013-EXCHZ                  2              0               Mailed check
# 0013-MHZWF                  1              0    Credit card (automatic)
# 0013-SMEOE                  2              2  Bank transfer (automatic)
# 0014-BMAQU                  2              2    Credit card (automatic)
# 0015-UOCOJ                  1              0           Electronic check
# 0016-QLJIS                  1              2               Mailed check
# 0017-DINOC                  1              2    Credit card (automatic)
# 0017-IUDMW                  2              2    Credit card (automatic)
# 0018-NYROU                  2              0           Electronic check
# 0019-EFAEP                  2              2  Bank transfer (automatic)
# 0019-GFNTW                  1              2  Bank transfer (automatic)
# 0020-INWCK                  2              2    Credit card (automatic)
# 0020-JDNXP                  1              1               Mailed check
# 0021-IKXGC                  2              0           Electronic check
# 0022-TCJCI                  1              1    Credit card (automatic)
# 0023-HGHWL                  1              0           Electronic check
# 0023-UYUPN                  0              1           Electronic check
# 0023-XUOPT                  2              0           Electronic check
# 0027-KWYKW                  2              0           Electronic check
# 0030-FNXPP                  0              0               Mailed check
# 0031-PVLZI                  0              0               Mailed check
# 0032-PGELS                  1              0  Bank transfer (automatic)
# 0036-IHMOT                  2              1  Bank transfer (automatic)
# 0040-HALCW                  0              2    Credit card (automatic)
# 0042-JVWOJ                  0              1  Bank transfer (automatic)
# 0042-RLHYP                  0              2  Bank transfer (automatic)
# 0048-LUMLS                  2              1    Credit card (automatic)
# 0048-PIHNL                  0              1  Bank transfer (automatic)
# 0052-DCKON                  2              1  Bank transfer (automatic)
# 0052-YNYOT                  0              1           Electronic check
# 0056-EPFBG                  1              2    Credit card (automatic)
# 0057-QBUQH                  0              2           Electronic check
# 0058-EVZWM                  2              0  Bank transfer (automatic)
# 0060-FUALY                  2              0           Electronic check
# 0064-SUDOG                  0              2  Bank transfer (automatic)
# 0064-YIJGF                  2              0  Bank transfer (automatic)
# 0067-DKWBL                  1              0           Electronic check
# 0068-FIGTF                  1              1               Mailed check
# 0071-NDAFP                  0              2    Credit card (automatic)
# 0074-HDKDG                  1              1  Bank transfer (automatic)
# 0076-LVEPS                  1              0               Mailed check
# 0078-XZMHT                  1              2  Bank transfer (automatic)
# 0080-EMYVY                  1              1    Credit card (automatic)
# 0080-OROZO                  2              1           Electronic check
# 0082-LDZUE                  1              0               Mailed check
# 0082-OQIQY                  2              0           Electronic check
# 0083-PIVIK                  1              1           Electronic check
# 0089-IIQKO                  2              0    Credit card (automatic)
# 0093-EXYQL                  2              0           Electronic check
# 0093-XWZFY                  2              0    Credit card (automatic)
# 0094-OIFMO                  2              0           Electronic check
# 0096-BXERS                  1              0           Electronic check
# 0096-FCPUF                  1              0               Mailed check
# 0098-BOWSO                  0              0           Electronic check
# 0100-DUVFC                  2              1           Electronic check
# 0103-CSITQ                  2              1  Bank transfer (automatic)
# 0104-PPXDV                  1              1    Credit card (automatic)
# 0106-GHRQR                  1              0  Bank transfer (automatic)
# 0106-UGRDO                  2              2           Electronic check
# 0107-WESLM                  0              0           Electronic check
# 0107-YHINA                  2              0           Electronic check
# 0111-KLBQG                  2              0               Mailed check
# 0112-QAWRZ                  2              0  Bank transfer (automatic)
# 0112-QWPNC                  1              1           Electronic check
# 0114-IGABW                  1              2  Bank transfer (automatic)
# 0114-PEGZZ                  2              0           Electronic check
# 0114-RSRRW                  0              0  Bank transfer (automatic)
# 0115-TFERT                  2              0           Electronic check
# 0117-LFRMW                  1              0  Bank transfer (automatic)
# 0118-JPNOY                  2              0    Credit card (automatic)
# 0121-SNYRK                  1              1               Mailed check
# 0122-OAHPZ                  2              0           Electronic check
# 0123-CRBRT                  1              2               Mailed check
# 0125-LZQXK                  2              0           Electronic check
# 0128-MKWSG                  1              0               Mailed check
# 0129-KPTWJ                  2              0           Electronic check
# 0129-QMPDR                  0              1  Bank transfer (automatic)
# 0130-SXOUN                  2              0    Credit card (automatic)
# 0133-BMFZO                  2              0           Electronic check
# 0134-XWXCE                  1              1  Bank transfer (automatic)
# 0135-NMXAP                  2              0  Bank transfer (automatic)
# 0136-IFMYD                  2              2           Electronic check
# 0137-OCGAB                  2              0               Mailed check
# 0137-UDEUO                  0              0               Mailed check
# 0139-IVFJG                  2              0           Electronic check
# 0141-YEAYS                  2              0  Bank transfer (automatic)
# 0142-GVYSN                  0              0           Electronic check
# 0147-ESWWR                  2              0           Electronic check
# 0148-DCDOS                  2              0  Bank transfer (automatic)
# 0151-ONTOV                  2              0               Mailed check
# 0156-FVPTA                  1              0           Electronic check
# 0164-APGRB                  2              2           Electronic check
# 0164-XAIRP                  0              2  Bank transfer (automatic)
# 0168-XZKBB                  2              0           Electronic check
# 0174-QRVVY                  0              2    Credit card (automatic)
# 0177-PXBAT                  2              0  Bank transfer (automatic)
#
#              monthly_charges  total_charges churn
# customer_id
# 0002-ORFBO             65.60         593.30    No
# 0003-MKNFE             59.90         542.40    No
# 0004-TLHLJ             73.90         280.85   Yes
# 0011-IGKFF             98.00        1237.85   Yes
# 0013-EXCHZ             83.90         267.40   Yes
# 0013-MHZWF             69.40         571.45    No
# 0013-SMEOE            109.70        7904.25    No
# 0014-BMAQU             84.65        5377.80    No
# 0015-UOCOJ             48.20         340.35    No
# 0016-QLJIS             90.45        5957.90    No
# 0017-DINOC             45.20        2460.55    No
# 0017-IUDMW            116.80        8456.75    No
# 0018-NYROU             68.95         351.50    No
# 0019-EFAEP            101.30        7261.25    No
# 0019-GFNTW             45.05        2560.10    No
# 0020-INWCK             95.75        6849.40    No
# 0020-JDNXP             61.25        1993.20    No
# 0021-IKXGC             72.10          72.10    No
# 0022-TCJCI             62.70        2791.50   Yes
# 0023-HGHWL             25.10          25.10   Yes
# 0023-UYUPN             25.20        1306.30    No
# 0023-XUOPT             94.10        1215.60   Yes
# 0027-KWYKW             83.75        1849.95    No
# 0030-FNXPP             19.85          57.20    No
# 0031-PVLZI             20.35          76.35   Yes
# 0032-PGELS             30.50          30.50   Yes
# 0036-IHMOT            103.70        5656.75    No
# 0040-HALCW             20.40        1090.60    No
# 0042-JVWOJ             19.60         471.85    No
# 0042-RLHYP             19.70        1396.90    No
# 0048-LUMLS             91.20        3247.55    No
# 0048-PIHNL             20.45         900.90    No
# 0052-DCKON            115.80        7942.15    No
# 0052-YNYOT             20.55        1343.40    No
# 0056-EPFBG             39.40         825.40    No
# 0057-QBUQH             25.10        1070.15    No
# 0058-EVZWM             89.80        4959.60    No
# 0060-FUALY             94.75        5597.65    No
# 0064-SUDOG             20.30         224.50    No
# 0064-YIJGF             75.75        1929.00    No
# 0067-DKWBL             49.25          91.10   Yes
# 0068-FIGTF             78.20        2078.95    No
# 0071-NDAFP             25.50         630.60    No
# 0074-HDKDG             61.60        1611.00    No
# 0076-LVEPS             45.00        1242.45    No
# 0078-XZMHT             85.15        6316.20    No
# 0080-EMYVY             51.45         727.85    No
# 0080-OROZO             99.25        3532.00    No
# 0082-LDZUE             44.30          44.30    No
# 0082-OQIQY             94.20        2607.60    No
# 0083-PIVIK             81.25        5567.55    No
# 0089-IIQKO             99.95        3767.40    No
# 0093-EXYQL             91.55        3673.60    No
# 0093-XWZFY            104.50        4036.85   Yes
# 0094-OIFMO             95.00        1120.30   Yes
# 0096-BXERS             50.35         314.55    No
# 0096-FCPUF             64.50        1888.45    No
# 0098-BOWSO             19.40         529.80    No
# 0100-DUVFC            104.80        7308.95    No
# 0103-CSITQ            109.40        6252.70    No
# 0104-PPXDV             50.30        2878.55    No
# 0106-GHRQR             71.40        1212.10    No
# 0106-UGRDO            116.00        8182.85    No
# 0107-WESLM             19.85          19.85   Yes
# 0107-YHINA             99.75          99.75   Yes
# 0111-KLBQG             93.95        2861.45    No
# 0112-QAWRZ             90.80        1442.20    No
# 0112-QWPNC             84.35        4059.35   Yes
# 0114-IGABW             58.25        4145.90    No
# 0114-PEGZZ            107.55        3645.50    No
# 0114-RSRRW             19.95         187.75    No
# 0115-TFERT            111.20        2317.10   Yes
# 0117-LFRMW             40.20        1448.80   Yes
# 0118-JPNOY             85.80        2193.65    No
# 0121-SNYRK             35.40        1748.90    No
# 0122-OAHPZ             73.85         511.25   Yes
# 0123-CRBRT             88.10        5526.75    No
# 0125-LZQXK            101.35        1553.95   Yes
# 0128-MKWSG             45.80        1147.00    No
# 0129-KPTWJ             94.65        6747.35    No
# 0129-QMPDR             20.50         865.05    No
# 0130-SXOUN             89.40        5976.90    No
# 0133-BMFZO             86.25         181.65   Yes
# 0134-XWXCE             74.85        3268.05    No
# 0135-NMXAP             89.75        1052.40   Yes
# 0136-IFMYD            109.95        7634.25    No
# 0137-OCGAB             80.20          80.20   Yes
# 0137-UDEUO             19.85          63.75   Yes
# 0139-IVFJG             90.35         190.50    No
# 0141-YEAYS             86.45        2401.05    No
# 0142-GVYSN             20.30         511.25    No
# 0147-ESWWR            101.25        3949.15    No
# 0148-DCDOS             94.70        2362.10   Yes
# 0151-ONTOV             70.90          70.90   Yes
# 0156-FVPTA             54.20        1152.70   Yes
# 0164-APGRB            114.90        8496.70    No
# 0164-XAIRP             19.55         470.20    No
# 0168-XZKBB             86.85        1564.40    No
# 0174-QRVVY             25.35        1847.55    No
# 0177-PXBAT            109.90        3694.70    No

# %%
titanic=pd.read_sql('SELECT * FROM passengers', get_connection('titanic_db'))

# %%
titanic.to_csv('titanic.csv')

# %%
def get_titanic_data():
    filename = "titanic.csv"
    if os.path.isfile(filename):
        return pd.read_csv(filename)
    else:
        # read the SQL query into a dataframe
        df = pd.read_sql('SELECT * FROM passengers', get_connection('titanic_db'))

        # Write that dataframe to disk for later. Called "caching" the data for later.
        df.to_file(filename)

        # Return the dataframe to the calling code
        return df
